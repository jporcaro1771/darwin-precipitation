# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import csv

# %%
txtfile = '/Users/joelporcaro/Desktop/rmm.74toRealtime.txt'
data = np.genfromtxt(txtfile, skip_header=2, dtype=float)
years = []
for i in data[:]:
    years.append(i[0])

amplitudes = []    
for i in data[:]:
    amplitudes.append(i[6])

# %%
years2 = []
for i in years:
    if i not in years2:
        years2.append(i)

# %%
del(years[1385:1675])
del(amplitudes[1385:1675])

fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(years, amplitudes)
plt.show()

# %%
# yearsAmplitudes = dict(zip(years, amplitudes))
# yAkeys = list(yearsAmplitudes.keys())
# yAvals = list(yearsAmplitudes.values())

q = list(zip(years, amplitudes))

D2 = {}
for (k,v) in zip(years, amplitudes):
    D2[k] = v
D2
# Out:
# {1974.0: 1.0874799,
#  1975.0: 1.4691,
#  1976.0: 1.47688,
#  1977.0: 0.45417401,
#  1978.0: 1.83373,
#  1979.0: 0.89867401,
#  1980.0: 1.02185,
#  1981.0: 1.6495,
#  1982.0: 0.99958998,
#  1983.0: 0.31055301,
#  1984.0: 1.31969,
#  1985.0: 2.1199,
#  1986.0: 1.31427,
#  1987.0: 1.6082799,
#  1988.0: 1.6210901,
#  1989.0: 1.6124099,
#  1990.0: 0.63936001,
#  1991.0: 0.471683,
#  1992.0: 2.09394,
#  1993.0: 0.94909602,
#  1994.0: 1.19629,
#  1995.0: 0.574274,
#  1996.0: 3.0242,
#  1997.0: 1.29483,
#  1998.0: 0.20342401,
#  1999.0: 0.20908099,
#  2000.0: 0.552091,
#  2001.0: 1.43321,
#  2002.0: 1.45832,
#  2003.0: 1.6279907,
#  2004.0: 1.2116482,
#  2005.0: 1.4960393,
#  2006.0: 2.319397,
#  2007.0: 1.5159999,
#  2008.0: 1.1826192,
#  2009.0: 2.0643959,
#  2010.0: 0.62307459,
#  2011.0: 1.59908,
#  2012.0: 1.1617635,
#  2013.0: 0.3286483,
#  2014.0: 1.4087019,
#  2015.0: 2.118432,
#  2016.0: 0.75161421,
#  2017.0: 0.77449703}

# %%
years2
# amplitudes2 = []
# Out:
# [1974.0,
#  1975.0,
#  1976.0,
#  1977.0,
#  1978.0,
#  1979.0,
#  1980.0,
#  1981.0,
#  1982.0,
#  1983.0,
#  1984.0,
#  1985.0,
#  1986.0,
#  1987.0,
#  1988.0,
#  1989.0,
#  1990.0,
#  1991.0,
#  1992.0,
#  1993.0,
#  1994.0,
#  1995.0,
#  1996.0,
#  1997.0,
#  1998.0,
#  1999.0,
#  2000.0,
#  2001.0,
#  2002.0,
#  2003.0,
#  2004.0,
#  2005.0,
#  2006.0,
#  2007.0,
#  2008.0,
#  2009.0,
#  2010.0,
#  2011.0,
#  2012.0,
#  2013.0,
#  2014.0,
#  2015.0,
#  2016.0,
#  2017.0]

# %%
avg = []
total = 0
count = 0

for e in
for i in years:
    if years[i] == 1974:
        total = years[i] + total
        count+=1
    avg.append(total/count)
# Out:
#   File "<ipython-input-22-3616baa36c4f>", line 5
#     for e in
#             ^
# SyntaxError: invalid syntax

# %%
len(years2)
# Out:
# 44

# %%
# %time
count = 0
start = 0
means = []
templist = []

for j in years2: # for each singular year
    for i in range(start, len(amplitudes)): 
        while years[i] == j:
            templist.append(amplitudes[i])
            i+=1
    tempMean = np.mean(templist)
    means.append(tempMean)
    start = i+1
    #append mean(templist) to means
    #empty temptlist maybe
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 7.87 µs

# %%
means
# Out:
# [0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
#  0.9161322355337144,
# ...
